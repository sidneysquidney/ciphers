# %%
# use perm2 to create a dic of all combos with thier letters in 
# words from letters for all individual letters - monogram words
# combine with union this big dict
# monogram_words = {l: set(words_from_letters(l, containing = True)) for l in alphabet}

# def bigram_words():
#     bigram_set = Permutations2(2)
#     bigram_set.permute([l for l in alphabet])
#     bigram_set.convert_to_combinations()
#     bigrams = [''.join(b) for b in bigram_set.result]
# #     print(monogram_words)
#     bigram_words = {b: monogram_words[b[0]].union(monogram_words[b[1]]) for b in bigrams}
#     return bigram_set.result, bigrams, bigram_words
    
# # print(len(bigram_words()))
# # print(bigram_words())
# # print(type(monogram_words['a']))

# %%
# # helper function for getting a key from an encrypted texts bigrams
# # go thorugh frequency list and the bigram list matching connections throught the box fitting method

# def bigram_boxfit(frequency_list):
# #     print(frequency_list)
#     dictionary = {l: None for l in alphabet}
#     taken_letters = []
#     count = 0
#     count2 = 0
#     for f in frequency_list:
#         trying_to_find = sum([1 for l in f if l not in dictionary.values()])
# #         print(trying_to_find)
# #         print(f)
#         if len(taken_letters) == 26:
#             break
#         count += 1
#         if trying_to_find == 0:
# #             print('both already assigned - move to next f')
#             continue
#         for b in bigrams_list:
#             count2 += 1
# #             print(b)
#             if b[0] in taken_letters and b[1] in taken_letters:
# #                 print('both bs already taken')
#                 continue
#             if b[0] not in taken_letters and b[1] not in taken_letters and trying_to_find == 2:
# #                 print('both not taken - asign accordingly')
#                 taken_letters += [b[0], b[1]]
#                 dictionary[b[0]], dictionary[b[1]] = f[0], f[1]
# #                 print(taken_letters)
# #                 print(dictionary)
#                 break
#             else:        
# #                 print('1 or more taken')
#                 if b[0] in taken_letters:
#                     if dictionary[b[0]] == f[0]:
#                         dictionary[b[1]] = f[1]
#                         taken_letters.append(b[1])
# #                         print(taken_letters)
# #                         print(dictionary)
#                         break
#                 else:
#                     if dictionary[b[1]] == f[1]:
#                         dictionary[b[0]] = f[0]
#                         taken_letters.append(b[0])
# #                         print(taken_letters)
# #                         print(dictionary)
#                         break
#                     continue
# #         print(count, count2)
#     return dictionary


# bee_encrypted_bigrams_frequency = [x[0] for x in find_ngrams(encrypted_bee, 2)]
# print(bigram_boxfit(bee_encrypted_bigrams_frequency))

# # just with either both match, or neither match, 1 match - 3637 count

# %%
# # get key for hill climb from list of bigrams using the box fitting algorithm

# def bigrams_hillclimb_key(encrypted_text):
#     frequency = find_ngrams(encrypted_text, 2)
#     frequency_list = [x[0] for x in frequency]
#     new_dictionary = bigram_boxfit(frequency_list)
#     return ''.join(new_dictionary.values())

# bigram_key = bigrams_hillclimb_key(encrypted_bee)
# score2(bigram_key, test_key, letters = True)

# # doesn't work yet. produces 2 z keys(at index 1 and...)

# %%
# # function to take a nearly complete decryption - list into words, dictionary attack, 
# # if not in dic then add words to incomplete - count the letters
# # return most frequenct letters of incomplete words - get permutations 

# def unfinished_key(decrypted_text):
#     word_list = turn_to_list(decrypted_text)
#     incomplete = [word for word in word_list if word not in common_words]
#     print(incomplete)
#     letters = find_ngrams(''.join(incomplete), 1, percentage = False)
#     letter_sum = sum([x[1] for x in letters]) 
#     should_be = [(x[0], (monograms[x[0].upper()] / 100) * letter_sum) for x in letters]
#     higher_than_normal = [letters[i][0] for i in range(len(letters)) if letters[i][1] > should_be[i][1]]
#     for i in range(len(letters)):
#         print(letters[i][1], should_be[i])
#     return higher_than_normal

# # first try didn't work as e still top - want incorrect letters top
# # try total count - calculate percentage there should be from frequency dict, minus that from the new dict
# # unfinished_key(decrypt(encrypted_bee, 'qisknoulvarzjmwcdetxphgfby'))

# %%
# # make a hill climb using the diciotnary attack by looping through a list of words 
# # and seeing if they are in common words

# def hillclimb_dictionary_attack(encrypted_text, start_key = None):
#     if not start_key:
#         start_key = hillclimb_key(encrypted_text)
# #     if len(encrypted_text) > 1000:
# #         encrypted_text = encrypted_text[:1000]
#     matches = code_matches(decrypt(encrypted_text, start_key))
#     key = start_key
#     potential_keys = MinHeapString()
#     potential_keys.add([start_key, matches])
#     under_10 = True
#     count = 0
#     while True:
#         count += 1
#         for i1 in range(len(key)):
#             for i2 in range(len(key)):
#                 if i1 == i2:
#                     continue
#                 key = swap(start_key, i1, i2)
#                 matches = code_matches(decrypt(encrypted_text, key))
# #                 print(key, matches)
#                 if under_10:
#                     print('under 10')
#                     potential_keys.add([key, matches])
#                     if potential_keys.count == 10:
#                         under_10 = False
#                 elif matches > potential_keys.heap_list[1][1]:
#                     potential_keys.add([key, matches])
#                     potential_keys.remove_min()
# #             print(potential_keys.heap_list)
#             print(potential_keys.max)
#         if start_key == potential_keys.max[0]:
#             print('reached max')
#             return potential_keys.heap_list
#             break
#         start_key = potential_keys.max[0]
    
# # - slow and doesn't really work

# %%
# # make a dictionary attack that doesn't account for spaces - use .count maybe
# # try to get it to work on the ciphertext

# def dictionary_attack2(encrypted_text, start_key = None):
#     if not start_key:
#         start_key = hillclimb_key(encrypted_text)
#     potential_keys = MinHeapString()
#     matches = sum([decrypt(encrypted_text, start_key).count(word) for word in common_words])
#     potential_keys.add([start_key, matches])
#     under_10 = True
#     while True:
#         key = start_key
#         for i1 in range(len(key)):
#             for i2 in range(len(key)):
#                 if i1 == i2:
#                     continue
#                 key = swap(start_key, i1, i2)
#                 matches = sum([decrypt(encrypted_text, key).count(word) for word in common_words])
#                 print(matches)
#                 if under_10:
#                     print('under 10')
#                     potential_keys.add([key, matches])
#                     if potential_keys.count == 10:
#                         under_10 = False
#                 elif matches > potential_keys.heap_list[1][1]:
#                     potential_keys.add([key, matches])
#                     potential_keys.remove_min()
#         break
# # dictionary_attack2(ciphertext, 'rvwaqpoixzctdsjbgknlyhufem')

# %%
# def dictionary_attack3(encrypted_text, key):
#     return sum([decrypt(encrypted_text, start_key).count(word) for word in common_words])

# %%
# switch keys to find the right key. input incorrect keys. 

# def dictionary_attack4(encrypted_text, start_key = None):
#     if not start_key:
#         start_key = hillclimb_key(encrypted_text)
#     while True:
#         print(decrypt(encrypted_text, start_key))
#         incorrect = input('what are the wrong letters?')
#         incorrect_indicies = [start_key.find(l) for l in incorrect]
#         key = start_key
#         for i1 in incorrect_indicies:
            
#             for i2 in range(len(key)):
# #                 print(i1, i2)
# #                 if i1 == i2:
# #                     continue
#                 letter1, letter2 = start_key[i1], start_key[i2]
#                 key = swap(start_key, i1, i2)
#                 print(letter1, letter2, key, score2(key, ckey))
#                 i1_matches = [word for word in containing_dictionary[letter1] if word in decrypt(encrypted_text, key)]
#                 i2_matches = [word for word in containing_dictionary[letter2] if word in decrypt(encrypted_text, key)]
#                 total_score = len(set(i1_matches + i2_matches))
# #                 print(i1_matches, i2_matches, total_score)
# #                 break
#                 print(decrypt(encrypted_text, key), i2)
#                 print()
#             correct_swap = input('What was the correct swap/(n)one')
#             if correct_swap != 'n':
#                 start_key = swap(start_key, i1, int(correct_swap))
#                 print(i1, correct_swap)
        
#         satisfied = input('(c)ontinue or (f)inish')
#         if satisfied == 'f':
#             break
#     return start_key, decrypt(encrypted_text, start_key)
# dictionary_attack4(ciphertext, fkey)

# %%
# # make a funciton to take a 3 params, whole order, letter you want to test, how many options you want. 
# # returns indices of the letters for you to test


# # find letter index
# # is letter even or odd
# # if odd easy, 
# # if even, divide to whichever half has more
# # if against the side, shift
# # add parameters, so can stop at a certain point(eg if etao have already been tested, can make start default after o...)
# def test_group(order, letter, how_many, s = 0, e = 25):
#     i = order.index(letter)
# #     print('index:')
# #     print(i)
# #     print('How many do you want:')
# #     print(how_many)
# #     print(f'start: {s}')
# #     print(f'end: {e}')
#     even = ((how_many % 2) == 0)
#     first_half = (i <= 12)
#     if even:
#         if first_half:
#             start = i - (how_many // 2 - 1)
#             end = i + (how_many // 2 + 1)
#         else:
#             start = i - (how_many // 2)
#             end = i + (how_many // 2)
#     else:
#         start = i - (how_many // 2)
#         end = i + (how_many // 2 + 1)
#     if start < s or end > e:
#         if abs(start - end) > abs(s - e):
#             return list(range(s, e))
#         lst = np.arange(start, end)
#         while lst[0] < s:
#             lst = lst + 1
#             print(lst)
#         while lst[-1] > e:
#             lst = lst - 1
#             print(lst)
#         return list(lst)
#     return list(range(start, end))
